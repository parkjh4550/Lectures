# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_path = '/content/drive/MyDrive/개인 연구/강의 수강/(패스트 캠퍼스) 데이터 분석/Ch5 Decision Tree/galaxy.csv'
data = pd.read_csv(data_path)

# %% [markdown]
# 데이터 특성 확인

# %%
data.head()
# Out:
#    BuyItNow  startprice  ... upperCaseDescription sold
# 0         0      199.99  ...                    0    1
# 1         0      235.00  ...                    0    0
# 2         0      199.99  ...                    2    0
# 3         1      175.00  ...                    0    1
# 4         1      100.00  ...                    0    1
#
# [5 rows x 9 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1485 entries, 0 to 1484
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   BuyItNow              1485 non-null   int64
#  1   startprice            1485 non-null   float64
#  2   carrier               1179 non-null   object
#  3   color                 892 non-null    object
#  4   productline           1485 non-null   object
#  5   noDescription         1485 non-null   object
#  6   charCountDescription  1485 non-null   int64
#  7   upperCaseDescription  1485 non-null   int64
#  8   sold                  1485 non-null   int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 104.5+ KB

# %%
data.describe()
# Out:
#           BuyItNow   startprice  ...  upperCaseDescription         sold
# count  1485.000000  1485.000000  ...           1485.000000  1485.000000
# mean      0.449158   216.844162  ...              2.863300     0.461953
# std       0.497576   172.893308  ...              9.418585     0.498718
# min       0.000000     0.010000  ...              0.000000     0.000000
# 25%       0.000000    80.000000  ...              0.000000     0.000000
# 50%       0.000000   198.000000  ...              0.000000     0.000000
# 75%       1.000000   310.000000  ...              2.000000     1.000000
# max       1.000000   999.000000  ...             81.000000     1.000000
#
# [8 rows x 5 columns]

# %%
sns.distplot(data['startprice'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(data['charCountDescription'])    # 대부분의 값이 0에 치우쳐져 있다.
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Box 그래프로 분포 확인
# Box 그래프 참고 블로그 : https://steadiness-193.tistory.com/193
# Outlier 기준 참고 블로그 : https://leebaro.tistory.com/entry/%EB%B0%95%EC%8A%A4-%ED%94%8C%EB%A1%AFbox-plot-%EC%84%A4%EB%AA%85#footnote_31_1
plt.figure(figsize=(20,10))
sns.boxplot(x='productline', y='startprice', data=data) # 각 product별로 시작 가격을 시각화

# %% [markdown]
# Missing Value 처리

# %%
# Missing Value 비율 확인
data.isna().sum() / len(data)
# Out:
# BuyItNow                0.000000
# startprice              0.000000
# carrier                 0.206061
# color                   0.399327
# productline             0.000000
# noDescription           0.000000
# charCountDescription    0.000000
# upperCaseDescription    0.000000
# sold                    0.000000
# dtype: float64

# %%
data.head()   # Unknown과 NaN, None이 존재한다
# Out:
#    BuyItNow  startprice  ... upperCaseDescription sold
# 0         0      199.99  ...                    0    1
# 1         0      235.00  ...                    0    0
# 2         0      199.99  ...                    2    0
# 3         1      175.00  ...                    0    1
# 4         1      100.00  ...                    0    1
#
# [5 rows x 9 columns]

# %%
data = data.fillna('Unknown')   # NaN 값들을 Unknown으로 변경
data.head()
# Out:
#    BuyItNow  startprice  ... upperCaseDescription sold
# 0         0      199.99  ...                    0    1
# 1         0      235.00  ...                    0    0
# 2         0      199.99  ...                    2    0
# 3         1      175.00  ...                    0    1
# 4         1      100.00  ...                    0    1
#
# [5 rows x 9 columns]

# %%
data['carrier'].value_counts()    # category별로 값 개수 확인
# Out:
# None               863
# Unknown            306
# AT&T               177
# Verizon             87
# Sprint/T-Mobile     52
# Name: carrier, dtype: int64

# %% [markdown]
# 카테고리 변수 처리

# %%
# 원하는 column의 unique한 category 개수 확인
columns = ['carrier', 'color', 'productline', 'noDescription']
data[columns].nunique()
# Out:
# carrier          5
# color            8
# productline      8
# noDescription    2
# dtype: int64

# %%
# 각 categroy별 데이터 개수 확인
for col in columns:
  print(col, '---------\n', data[col].value_counts())
# Out:
# carrier ---------
#  None               863
# Unknown            306
# AT&T               177
# Verizon             87
# Sprint/T-Mobile     52
# Name: carrier, dtype: int64
# color ---------
#  Unknown           593
# White             328
# Midnight Black    274
# Space Gray        180
# Gold               52
# Black              38
# Aura Black         19
# Prism Black         1
# Name: color, dtype: int64
# productline ---------
#  Galaxy_Note10    351
# Galaxy_S8        277
# Galaxy_S7        227
# Unknown          204
# Galaxy_S9        158
# Galaxy_Note8     153
# Galaxy_Note9     107
# Galaxy_S10         8
# Name: productline, dtype: int64
# noDescription ---------
#  contains description    856
# no description          629
# Name: noDescription, dtype: int64

# %%
# Color에서 비슷한 category 통합 : Black color는 Black, Aura Black, Prism Black
list_blacks = ['Midnight Black', 'Aura Black', 'Prism Black']
def integrate_black_color(color):
  if color in list_blacks:
    return 'Black'
  return color

data['color'] = data['color'].apply(lambda x:integrate_black_color(x))
data['color'].value_counts()
# Out:
# Unknown       593
# Black         332
# White         328
# Space Gray    180
# Gold           52
# Name: color, dtype: int64
