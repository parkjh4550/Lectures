# %% [markdown]
# # Download and Unzip

# %%
# !wget https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip -P /resources/data
# Out:
# --2021-12-07 09:48:11--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0321EN/data/images/concrete_crack_images_for_classification.zip
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 245259777 (234M) [application/zip]
# Saving to: ‘/resources/data/concrete_crack_images_for_classification.zip’
#
# concrete_crack_imag 100%[===================>] 233.90M  24.0MB/s    in 8.8s
#
# 2021-12-07 09:48:20 (26.4 MB/s) - ‘/resources/data/concrete_crack_images_for_classification.zip’ saved [245259777/245259777]

# %%
# !unzip -q  /resources/data/concrete_crack_images_for_classification.zip -d  /resources/data

# %% [markdown]
# # Imports and Auxiliary Functions

# %%
from PIL import Image
from matplotlib.pyplot import imshow
import pandas
import matplotlib.pylab as plt
import os
import glob

# %%
def show_data(data_sample, shape = (28, 28)):
  plt.imshow(data_sample[0].numpy().reshape(shape), cmap='gray')
  plt.title('y = ' + data_sample[1])

# %% [markdown]
# # Examine Files

# %%
file_dir = '/resources/data'

# %%
negative = 'Negative'
positive = 'Positive'

# %%
neg_file_path = os.path.join(file_dir, negative)
pos_file_path = os.path.join(file_dir, positive)
print(neg_file_path)
print(pos_file_path)
# Out:
# /resources/data/Negative
# /resources/data/Positive

# %% [markdown]
# ## Load each Image

# %%
os.listdir(neg_file_path)[0:3]
# Out:
# ['09440.jpg', '19632.jpg', '11165.jpg']

# %%
[os.path.join(neg_file_path, file) for file in os.listdir(neg_file_path)][0:3]
# Out:
# ['/resources/data/Negative/09440.jpg',
#  '/resources/data/Negative/19632.jpg',
#  '/resources/data/Negative/11165.jpg']

# %%
print('test.jpg'.endswith('.jpg'))
print('test.mpg'.endswith('.jpg'))
# Out:
# True
# False

# %%
neg_files = [os.path.join(neg_file_path, file) for file in os.listdir(neg_file_path) if file.endswith('.jpg')]
neg_files.sort()
neg_files[0:3]
# Out:
# ['/resources/data/Negative/00001.jpg',
#  '/resources/data/Negative/00002.jpg',
#  '/resources/data/Negative/00003.jpg']

# %%
pos_files = [os.path.join(pos_file_path, file) for file in os.listdir(pos_file_path) if file.endswith('.jpg')]
pos_files.sort()
pos_files[0:3]
# Out:
# ['/resources/data/Positive/00001.jpg',
#  '/resources/data/Positive/00002.jpg',
#  '/resources/data/Positive/00003.jpg']

# %% [markdown]
# # Display and Analyze Image with No Cracks

# %%
image1 = Image.open(neg_files[0])
plt.imshow(image1)
plt.title('1st Image with No Cracks')
plt.show()

# %%
image2 = Image.open(neg_files[1])
plt.imshow(image2)
plt.title('2nd Image with No Cracks')
plt.show()

# %%
image3 = Image.open(pos_files[0])
plt.imshow(image3)
plt.title('1st Image with Cracks')
plt.show()

# %%
image4 = Image.open(pos_files[1])
plt.imshow(image4)
plt.title('2nd Image with Cracks')
plt.show()

# %%
import numpy as np
np.array(image4).shape
# Out:
# (227, 227, 3)

# %%
image3 = Image.open(neg_files[2])
plt.imshow(image3)
plt.title('1st Image with Cracks')
plt.show()
